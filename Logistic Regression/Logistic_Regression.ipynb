# %%
# Linear Regression   1. Home prices 2.Weather ,3.Stock price 
# Predicated value is continous#

# %%
# Predicted value is categorical
# Logistic regression is one of the techniques used for classification

# %%
# Classification Types 
# Will customer buy life insurance ? Yes , No

# 1/1+e

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Logistic.csv')
df.head()
# Out:
#    age  have_insurance
# 0   22               0
# 1   25               0
# 2   47               1
# 3   52               0
# 4   46               1

# %%
plt.scatter(df.age,df.have_insurance , marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train ,y_test =train_test_split(df[['age']],df.have_insurance , test_size=0.1)

# %%
len(X_train)
# Out:
# 24

# %%
len(X_test)
# Out:
# 3

# %%
X_test
# Out:
#     age
# 18   19
# 11   28
# 26   23

# %%
X_train
# Out:
#     age
# 9    61
# 21   26
# 15   55
# 8    62
# 16   25
# 14   49
# 20   21
# 10   18
# 24   50
# 6    55
# 12   27
# 7    60
# 23   45
# 19   18
# 0    22
# 3    52
# 4    46
# 13   29
# 2    47
# 5    56
# 17   58
# 22   40
# 25   54
# 1    25

# %%
from sklearn.linear_model import LogisticRegression
model =LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 18   19
# 11   28
# 26   23

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0])

# %%
model.predict([[31]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.9105015 , 0.0894985 ],
#        [0.76906359, 0.23093641],
#        [0.86097883, 0.13902117]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
# kaggle sy HR analytist ka data lena hai
